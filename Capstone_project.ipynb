# %% [markdown]
# # Applied Data Science Capstone Project
#
#
#
# # Extending Pharmacy Business in Hamburg
#
#
# # 1. introduction
#
# The project consists of supporting the stakeholders of a small Pharmacy franchise to extend their business in Hamburg. By leveraging the Foursquare location data, Hamburg neighborhood will be investigated based on their similar characteristics and availability of drugstore.
#
# Besides, available government data on the Hamburg population by districts, age, and gender will support the selection of the most promising region for the new business, since the proportion of the people using prescribed medicines typically increase with age.

# %% [markdown]
# # 2. Data Description
#
# Two sets of data will be required for this project. The first set of data consists of the information of Hamburg districts and their geographical location. Such information is available at  https://www.geonames.org/postal-codes/DE/HH/hamburg.html.
#
# These data will be scraped and combined with the population data provided by the statistic office of Hamburg (Statistisches Amt für Hamburg und Schleswig-Holstein). The population data is available at https://www.statistik-nord.de/fileadmin/Dokumente/Statistische_Berichte/bevoelkerung/A_I_S_1_j_H/A_I_S1_j18.pdf.
#
# Finally, the districts of Hamburg will be clustered based on their similarities using Foursquare location data and the most promising district will be selected based on their population information, as well as, availability of pharmacies.

# %% [markdown]
# # 3. Data scrapping
#
#
# ## 3.1 Importing libraries
# First the libraries required for data scrapping and processing are imported

# %%
#importing required libraries

import pandas as pd # library to process data as dataframes
from pandas.io.html import read_html

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %% [markdown]
# ## 3.2 Hamburg data

# %% [markdown]
# ### 3.2.1 Importing hamburg geo data
# The information list of hamburg districts was imported from https://www.geonames.org/postal-codes/DE/HH/hamburg.html

# %%
#importing table from website
path = 'https://www.geonames.org/postal-codes/DE/HH/hamburg.html'

restable = read_html(path,  attrs={"class":"restable"})
print ("Extracted {num} restabl".format(num=len(restable)))
# Out:
# Extracted 1 restabl

# %%
#print table head
df=restable[0]
df.head()
# Out:
#    Unnamed: 0          Place           Code        Country         Admin1  \
# 0         1.0        Hamburg          20095        Germany        Hamburg
# 1         NaN      53.552/10      53.552/10      53.552/10      53.552/10
# 2         2.0        Hamburg          20097        Germany        Hamburg
# 3         NaN  53.548/10.019  53.548/10.019  53.548/10.019  53.548/10.019
# 4         3.0        Hamburg          20099        Germany        Hamburg
#
#           Admin2                         Admin3                         Admin4
# 0            NaN  Hamburg, Freie und Hansestadt  Hamburg, Freie und Hansestadt
# 1      53.552/10                      53.552/10                      53.552/10
# 2            NaN  Hamburg, Freie und Hansestadt  Hamburg, Freie und Hansestadt
# 3  53.548/10.019                  53.548/10.019                  53.548/10.019
# 4            NaN  Hamburg, Freie und Hansestadt  Hamburg, Freie und Hansestadt

# %%
# assining pair indexes to df1, which contain information on hamburg neighborhoods
df1 = df[::2] 
df1.head()
# Out:
#    Unnamed: 0    Place   Code  Country   Admin1 Admin2  \
# 0         1.0  Hamburg  20095  Germany  Hamburg    NaN
# 2         2.0  Hamburg  20097  Germany  Hamburg    NaN
# 4         3.0  Hamburg  20099  Germany  Hamburg    NaN
# 6         4.0  Hamburg  20146  Germany  Hamburg    NaN
# 8         5.0  Hamburg  20148  Germany  Hamburg    NaN
#
#                           Admin3                         Admin4
# 0  Hamburg, Freie und Hansestadt  Hamburg, Freie und Hansestadt
# 2  Hamburg, Freie und Hansestadt  Hamburg, Freie und Hansestadt
# 4  Hamburg, Freie und Hansestadt  Hamburg, Freie und Hansestadt
# 6  Hamburg, Freie und Hansestadt  Hamburg, Freie und Hansestadt
# 8  Hamburg, Freie und Hansestadt  Hamburg, Freie und Hansestadt

# %%
# rows containing only hamburg were deleted since it reflects only Hamburg latitude and longitue, not assigned for a neighborhood
df2 = df1.iloc[97:401, 0:3]
df2.reset_index(inplace=True)
df2.drop(['index', 'Unnamed: 0'], axis=1, inplace=True)
df2.replace(regex=['Hamburg'], value=' ', inplace=True)
df2.head()
# Out:
#           Place   Code
# 0       Harburg  21073
# 1       Harburg  21079
# 2      Tonndorf  22045
# 3    Uhlenhorst  22085
# 4                22115

# %%
# assining pair indexes to df1, which contain information on hamburg neighborhoods
df3 = df[1::2] 
df3.reset_index(inplace=True)
df3.head()
# Out:
#    index  Unnamed: 0          Place           Code        Country  \
# 0      1         NaN      53.552/10      53.552/10      53.552/10
# 1      3         NaN  53.548/10.019  53.548/10.019  53.548/10.019
# 2      5         NaN  53.558/10.011  53.558/10.011  53.558/10.011
# 3      7         NaN    53.567/9.98    53.567/9.98    53.567/9.98
# 4      9         NaN   53.567/9.998   53.567/9.998   53.567/9.998
#
#           Admin1         Admin2         Admin3         Admin4
# 0      53.552/10      53.552/10      53.552/10      53.552/10
# 1  53.548/10.019  53.548/10.019  53.548/10.019  53.548/10.019
# 2  53.558/10.011  53.558/10.011  53.558/10.011  53.558/10.011
# 3    53.567/9.98    53.567/9.98    53.567/9.98    53.567/9.98
# 4   53.567/9.998   53.567/9.998   53.567/9.998   53.567/9.998

# %%
# cleaning the latitude and longitude data
df4 = df3.iloc[97:200, 0:3]
df4.reset_index(inplace=True)
df4.drop(['level_0', 'index', 'Unnamed: 0'], axis=1, inplace=True)
df4.head()
df4[['latitude','longitude']] = df4.Place.str.split(pat ='/', expand=True)
del df4['Place']
df4.head()
# Out:
#   latitude longitude
# 0   53.459     9.981
# 1   53.459     9.981
# 2   53.587    10.117
# 3   53.571    10.019
# 4   53.528    10.147

# %%
#merging the latitude-longitude dataframe (df4) with the Neighborhood-postal code dataframe (df2)
df5 = pd.concat([df2, df4.reindex(df2.index)], axis=1) #merging the dataframes

df5.rename(columns={'Place': 'Neighborhood', 'Code': 'Postal Code', 'latitude': 'Latitude', 'longitude': 'Longitude'}, inplace=True)

#entering missing information
df5.iloc[4,0] = 'Billstedt'
df5.iloc[5,0] = 'Langenhorn'

#correction german characters
df5.replace(regex=['Ã¼'], value='ü', inplace=True)
df5.replace(regex=['Ã¶'], value='ö', inplace=True)
df5.replace(regex=['Ã'], value='ß', inplace=True)

df5
# Out:
#                Neighborhood Postal Code Latitude Longitude
# 0                   Harburg       21073   53.459     9.981
# 1                   Harburg       21079   53.459     9.981
# 2                  Tonndorf       22045   53.587    10.117
# 3                Uhlenhorst       22085   53.571    10.019
# 4                 Billstedt       22115   53.528    10.147
# 5                Langenhorn       22417   53.667    10.034
# 6                  Ottensen       22765   53.555     9.918
# 7                  Altstadt       20095   53.545     9.995
# 8                Eimsbüttel       20144   53.572      9.95
# 9                 Eppendorf       20249   53.589     9.981
# 10                Eppendorf       20251   53.589     9.981
# 11               Eimsbüttel       20255   53.572      9.95
# 12               Eimsbüttel       20259   53.572      9.95
# 13                 Neustadt       20354    53.55     9.979
# 14              Kirchwerder       21037    53.44    10.172
# 15             Wilhelmsburg       21107   53.498    10.019
# 16             Finkenwerder       21129    53.53     9.869
# 17                 Wandsbek       22041   53.579    10.086
# 18              Barmbek-Süd       22083    53.58    10.044
# 19                   Eilbek       22089   53.566    10.047
# 20                Rahlstedt       22143   53.609    10.193
# 21                Rahlstedt       22149   53.607    10.161
# 22            Farmsen-Berne       22159   53.608    10.127
# 23             Barmbek-Nord       22305   53.596    10.051
# 24              Fuhlsbüttel       22339   53.629    10.016
# 25            Hummelsbüttel       22339   53.654    10.049
# 26           Wellingsbüttel       22391   53.643     10.09
# 27                    Sasel       22393   53.652    10.117
# 28             Poppenbüttel       22399   53.656    10.074
# 29               Langenhorn       22415   53.663    10.008
# 30               Langenhorn       22419   53.663    10.008
# 31                Schnelsen       22457   53.636     9.931
# 32                 Niendorf       22459   53.619     9.961
# 33               Eidelstedt       22523   53.605     9.916
# 34               Stellingen       22525   53.591      9.94
# 35               Stellingen       22527   53.591      9.94
# 36                 Lokstedt       22529   53.603     9.956
# 37                    Lurup       22547   53.594     9.874
# 38                   Rissen       22559   53.585     9.756
# 39               Blankenese       22587   53.557     9.803
# 40                 Ottensen       22763   53.555     9.918
# 41          Altona-Altstadt       22767    53.55     9.935
# 42              Altona-Nord       22769   53.561     9.945
# 43              Hammerbrook       20097   53.547    10.031
# 44              Sankt Georg       20099   53.556    10.014
# 45             Harvestehude       20144   53.576     9.987
# 46             Harvestehude       20146   53.576     9.987
# 47             Harvestehude       20148   53.576     9.987
# 48             Harvestehude       20149   53.576     9.987
# 49             Hoheluft-Ost       20251   53.583     9.981
# 50               Eimsbüttel       20253   53.572      9.95
# 51            Hoheluft-West       20253   53.581     9.968
# 52               Eimsbüttel       20257   53.572      9.95
# 53                 Neustadt       20355    53.55     9.979
# 54               Eimsbüttel       20357   53.572      9.95
# 55              Sankt Pauli       20359   53.551      9.97
# 56                 Neustadt       20459    53.55     9.979
# 57                Hamm-Nord       20535    53.56    10.051
# 58               Hamm-Mitte       20537   53.553    10.051
# 59           Rothenburgsort       20539   53.536    10.037
# 60                Lohbrügge       21031   53.509    10.198
# 61                Allermöhe       21035   53.484    10.125
# 62             Ochsenwerder       21037   53.472    10.094
# 63                Eißendorf       21073   53.451     9.935
# 64                  Harburg       21075   53.459     9.981
# 65                Marmstorf       21077   53.434     9.959
# 66             Wilhelmsburg       21109   53.498    10.019
# 67       Neugraben-Fischbek       21149   53.477     9.846
# 68               Marienthal       22041   53.559    10.086
# 69               Marienthal       22043   53.559    10.086
# 70                  Jenfeld       22043   53.577    10.128
# 71                  Jenfeld       22045   53.577    10.128
# 72                 Wandsbek       22047   53.579    10.086
# 73                 Wandsbek       22049   53.579    10.086
# 74                 Dulsberg       22049   53.583    10.062
# 75              Barmbek-Süd       22081    53.58    10.044
# 76               Uhlenhorst       22087   53.571    10.019
# 77               Hohenfelde       22087   53.563    10.026
# 78                 Wandsbek       22089   53.579    10.086
# 79                Billstedt       22111   53.541    10.124
# 80                     Horn       22111   53.554    10.103
# 81                Billstedt       22117   53.541    10.124
# 82                Billstedt       22119   53.541    10.124
# 83                     Horn       22119   53.554    10.103
# 84                Rahlstedt       22147   53.607    10.161
# 85             Barmbek-Nord       22307   53.596    10.051
# 86               Steilshoop       22309   53.616    10.057
# 87              Fuhlsbüttel       22335   53.629    10.016
# 88                 Ohlsdorf       22335   53.622    10.041
# 89                 Ohlsdorf       22337   53.622    10.041
# 90             Poppenbüttel       22391   53.656    10.074
# 91                Bergstedt       22395   53.667    10.131
# 92                    Sasel       22395   53.652    10.117
# 93               Duvenstedt       22397   53.707    10.094
# 94     Lemsahl-Mellingstedt       22397   53.681    10.087
# 95               Langenhorn       22417   53.663    10.008
# 96                 Niendorf       22453   53.619     9.961
# 97             Groß Borstel       22453   53.609     9.987
# 98                 Niendorf       22455   53.619     9.961
# 99                Schnelsen       22459   53.636     9.931
# 100              Eidelstedt       22525   53.605     9.916
# 101               Eppendorf       22529   53.589     9.981
# 102                   Lurup       22549   53.594     9.874
# 103                     NaN         NaN      NaN       NaN

# %% [markdown]
# ### 3.2.1 Importing hamburg population data
#
# Scrapping the Population data provided by the statistic office of Hamburg (Statistisches Amt für Hamburg und Schleswig-Holstein). The population data is available at https://www.statistik-nord.de/fileadmin/Dokumente/Statistische_Berichte/bevoelkerung/A_I_S_1_j_H/A_I_S1_j18.pdf.

# %%
#reading the data into a pd df
df_pop = pd.read_excel('https://www.statistik-nord.de/fileadmin/Dokumente/Statistische_Berichte/bevoelkerung/A_I_S_1_j_H/A_I_S1_j18.xlsx', 
                   'T3_1',
                   header=3)

df_pop.drop(0, inplace=True)
df_pop.drop(1, inplace=True)

df_pop = df_pop.rename(columns={'Unnamed: 0': 'Neighborhood', 'Unnamed: 1': 'Gender', 'Unnamed: 2': 'Total', '65 und \nälter': 'Older than 65'})
df_pop.head(15)
# Out:
#    Neighborhood  Gender    Total  0 – 3  3 – 6  6 – 12  12 – 18  18 – 20  \
# 2       Hamburg  männl.   1197.0   45.0   38.0    26.0     30.0     11.0
# 3      Altstadt  weibl.   1075.0   47.0   24.0    38.0     29.0     13.0
# 4           NaN    zus.   2272.0   92.0   62.0    64.0     59.0     24.0
# 5     HafenCity  männl.   2408.0  152.0   93.0   132.0    100.0     39.0
# 6           NaN  weibl.   2184.0  121.0  113.0   127.0     70.0     53.0
# 7           NaN    zus.   4592.0  273.0  206.0   259.0    170.0     92.0
# 8      Neustadt  männl.   6761.0  202.0  155.0   195.0    200.0     77.0
# 9           NaN  weibl.   6159.0  190.0  128.0   194.0    185.0     82.0
# 10          NaN    zus.  12920.0  392.0  283.0   389.0    385.0    159.0
# 11     St.Pauli  männl.  11934.0  322.0  302.0   485.0    422.0    161.0
# 12          NaN  weibl.  10502.0  326.0  283.0   447.0    398.0    137.0
# 13          NaN    zus.  22436.0  648.0  585.0   932.0    820.0    298.0
# 14     St.Georg  männl.   6418.0  163.0   97.0   156.0    152.0     78.0
# 15          NaN  weibl.   4966.0  140.0  109.0   177.0    152.0     84.0
# 16          NaN    zus.  11384.0  303.0  206.0   333.0    304.0    162.0
#
#     20 – 30  30 – 45  45 – 60  60 – 65  Older than 65
# 2     187.0    411.0    284.0     50.0          115.0
# 3     180.0    365.0    201.0     48.0          130.0
# 4     367.0    776.0    485.0     98.0          245.0
# 5     407.0    691.0    505.0     79.0          210.0
# 6     374.0    691.0    345.0     76.0          214.0
# 7     781.0   1382.0    850.0    155.0          424.0
# 8     940.0   2066.0   1673.0    341.0          912.0
# 9     998.0   1878.0   1281.0    276.0          947.0
# 10   1938.0   3944.0   2954.0    617.0         1859.0
# 11   1746.0   3852.0   2974.0    528.0         1142.0
# 12   1832.0   3543.0   2108.0    388.0         1040.0
# 13   3578.0   7395.0   5082.0    916.0         2182.0
# 14   1238.0   1890.0   1609.0    317.0          718.0
# 15   1031.0   1322.0    946.0    227.0          778.0
# 16   2269.0   3212.0   2555.0    544.0         1496.0

# %% [markdown]
# Data scrapping to be concluded during the Week5

# %% [markdown]
# Plan B: getting Hamburg geographical coordinates

# %%
address = 'Hamburg, HH'

geolocator = Nominatim(user_agent="Hamburg")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of Hamburg are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Hamburg are 53.5504683, 9.99464.

# %%
import geocoder # import geocoder

# initialize your variable to None
lat_lng_coords = None
postal_code = ()

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Hamburg, HH'.format(postal_code))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
